# %%
# Dependencies
import pandas as pd

# %%
# Store filepath in a variable
file_one = "ride_data_unzipped/JC-201712-citibike-tripdata.csv"

# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
df = pd.read_csv(file_one)

# %%
df.head()
# Out:
#    Trip Duration      Start Time       Stop Time  Start Station ID  \
# 0            452  12/1/2017 0:00  12/1/2017 0:08              3183
# 1            159  12/1/2017 0:04  12/1/2017 0:07              3187
# 2            175  12/1/2017 0:17  12/1/2017 0:19              3186
# 3            455  12/1/2017 0:50  12/1/2017 0:57              3194
# 4            670  12/1/2017 0:55  12/1/2017 1:06              3194
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0     Exchange Place               40.716247               -74.033459
# 1          Warren St               40.721124               -74.038051
# 2      Grove St PATH               40.719586               -74.043117
# 3    McGinley Square               40.725340               -74.067622
# 4    McGinley Square               40.725340               -74.067622
#
#    End Station ID      End Station Name  End Station Latitude  \
# 0            3199          Newport Pkwy             40.728745
# ...

# %%
df.columns
# Out:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
#reduced_kickstarter_df = df.loc[:,["name", "goal", "pledged", "state", "country", "staff_pick","backers_count", "spotlight"]]
station_data_dups = df.loc[:,["Start Station ID","Start Station Name","Start Station Latitude","Start Station Longitude"]]

# %%
station_data = station_data_dups.drop_duplicates("Start Station ID",keep="first")

# %%
station_data
# Out:
#       Start Station ID       Start Station Name  Start Station Latitude  \
# 0                 3183           Exchange Place               40.716247
# 1                 3187                Warren St               40.721124
# 2                 3186            Grove St PATH               40.719586
# 3                 3194          McGinley Square               40.725340
# 5                 3272             Jersey & 3rd               40.723332
# 6                 3213           Van Vorst Park               40.718489
# 7                 3209             Brunswick St               40.724176
# 8                 3267             Morris Canal               40.712419
# 9                 3269          Brunswick & 6th               40.726012
# 10                3276         Marin Light Rail               40.714584
# 12                3214         Essex Light Rail               40.712774
# 13                3279              Dixon Mills               40.721630
# ...
